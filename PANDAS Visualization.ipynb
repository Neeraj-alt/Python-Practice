# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.DataFrame(np.random.randn(5,4),columns=['A','B','C','D'])
print(df)
df.plot.bar()
# Out:
#           A         B         C         D
# 0 -0.670843  0.141897  0.036365 -0.051566
# 1 -1.717045  1.828520 -0.494600 -0.589388
# 2  0.557401  1.146810 -1.625566  0.457078
# 3  0.661397 -0.486206 -1.536020 -1.054561
# 4 -1.172871  0.165568 -0.176369 -0.858915
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(6,4),columns=['a','b','c','d'])
print(df)
df.plot.scatter(x='a',y='b')
# Out:
#           a         b         c         d
# 0  0.069399  1.079336 -0.839717  0.733385
# 1  0.579044 -0.451379  0.655022  0.795260
# 2  0.580404 -2.289380 -0.080384 -1.832325
# 3  1.656552  0.942358 -0.286097  1.064163
# 4  0.144259  0.109106  0.332251 -1.620990
# 5 -2.334300  0.067902 -0.688835 -0.294268
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
g=pd.DataFrame({'Day':[1,2,3,4],'Visitors':[200,300,400,500],'Bounce_rate':[20,25,45,12]})
g
# Out:
#    Day  Visitors  Bounce_rate
# 0    1       200           20
# 1    2       300           25
# 2    3       400           45
# 3    4       500           12

# %%
g1=g.set_index('Day')
g1
# Out:
#      Visitors  Bounce_rate
# Day
# 1         200           20
# 2         300           25
# 3         400           45
# 4         500           12

# %%
u=pd.read_csv('HRdata.csv')
u
# Out:
#    Name       hired  Sick Leave
# 0  Jaya  2018-12-24          13
# 1  hARA  2018-12-24          12
# 2   ERT  2018-12-24          34
# 3   ASF  2018-12-24          12
# 4    ER  2018-12-24          22
# 5    TE  2018-12-24          98

# %%
print(type(u['hired'][0]))
# Out:
# <class 'str'>

# %%
u1=pd.read_csv('HRdata.csv',index_col=['Name'],parse_dates=['hired'])
u1
# Out:
#           hired  Sick Leave
# Name
# Jaya 2018-12-24          13
# hARA 2018-12-24          12
# ERT  2018-12-24          34
# ASF  2018-12-24          12
# ER   2018-12-24          22
# TE   2018-12-24          98

# %%
print(type(u1['hired'][3]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
u2=pd.read_csv('HRdata.csv',
               index_col='Employee Name',
               parse_dates=['Hired'],
               header=0,
               names=['Employee Name','Hired','Sick Leaves taken'])
print(u2)
# Out:
#                    Hired  Sick Leaves taken
# Employee Name
# Jaya          2018-12-24                 13
# hARA          2018-12-24                 12
# ERT           2018-12-24                 34
# ASF           2018-12-24                 12
# ER            2018-12-24                 22
# TE            2018-12-24                 98
