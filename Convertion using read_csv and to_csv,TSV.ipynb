# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("HRdata.csv")
df
# Out:
#    Name       hired  Sick Leave
# 0  Jaya  2018-12-24          13
# 1  hARA  2018-12-24          12
# 2   ERT  2018-12-24          34
# 3   ASF  2018-12-24          12
# 4    ER  2018-12-24          22
# 5    TE  2018-12-24          98

# %%
print(type(df['hired'][0]))
# Out:
# <class 'str'>

# %%
print(type(df['hired'][3]))
# Out:
# <class 'str'>

# %%
df=pd.read_csv('HRdata.csv',
              index_col='Employee',
              parse_dates=['hired'],
              header=0,
              names=['Employee','hired','Sick Leave'])

# %%
df
# Out:
#               hired  Sick Leave
# Employee
# Jaya     2018-12-24          13
# hARA     2018-12-24          12
# ERT      2018-12-24          34
# ASF      2018-12-24          12
# ER       2018-12-24          22
# TE       2018-12-24          98

# %%
print(type(df['hired'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.to_csv('ModifiedHRdata.csv')

# %%
df.plot.bar('Sick Leave')
# Out:
# <AxesSubplot:xlabel='Sick Leave'>

# %%
t=pd.read_csv('DATAset1.csv')

# %%
print(t)
# Out:
#            date  temperature   humidity  windspeed       count
# 0    2011-01-03     2.716070  45.715346  21.414957  120.000000
# 1    2011-01-04     2.896673  54.267219  15.136882  108.000000
# 2    2011-01-05     4.235654  45.697702  17.034578   82.000000
# 3    2011-01-06     3.112643  50.237349  10.091568   88.000000
# 4    2011-01-07     2.723918  49.144928  15.738204  148.000000
# ..          ...          ...        ...        ...         ...
# 186  2011-07-08    28.187490  63.618656  19.761499  692.000000
# 187  2011-07-09    29.070524  61.346450  21.121738  702.333333
# 188  2011-07-10    29.953558  59.074244  22.481976  712.666667
# 189  2011-07-11    30.836592  56.802038  23.842215  723.000000
# 190  2011-07-12    32.409522  52.521355  17.987135  662.000000
#
# [191 rows x 5 columns]

# %%
df=pd.read_csv('empl.csv')
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df=pd.read_csv('empl.csv',index_col='SNo')

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Name'].count()
# Out:
# 22

# %%
df['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df['Name'].describe()
# Out:
# count       22
# unique      14
# top       yami
# freq         2
# Name: Name, dtype: object

# %%
df.describe()
# Out:
#              Age        Salary
# count  19.000000     19.000000
# mean   32.421053  33739.947368
# std     7.174924  23151.188084
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  33451.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %%
df.describe(include='all')
# Out:
#         Name        Age     City  Country        Salary
# count     22  19.000000       19       22     19.000000
# unique    14        NaN       10        5           NaN
# top     yami        NaN  newyork  America           NaN
# freq       2        NaN        4        8           NaN
# mean     NaN  32.421053      NaN      NaN  33739.947368
# std      NaN   7.174924      NaN      NaN  23151.188084
# min      NaN  22.000000      NaN      NaN   3900.000000
# 25%      NaN  27.000000      NaN      NaN   8888.000000
# 50%      NaN  31.000000      NaN      NaN  33451.000000
# 75%      NaN  36.000000      NaN      NaN  54666.000000
# max      NaN  50.000000      NaN      NaN  67666.000000

# %%
df.drop([1,2,3],inplace=True)

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df.drop([12,13,14],inplace=True)

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df.drop('Name',axis=1)
# Out:
#       Age       City  Country   Salary
# SNo
# 4    26.0   HongKong     Asia  66672.0
# 5    30.0        NaN  America      NaN
# 6     NaN   HongKong     Asia  30007.0
# 7    43.0    BayArea  America   8300.0
# 8    38.0  Hyderabad     Asia  54666.0
# 9    50.0    newyork  America  67666.0
# 11    NaN    newyork  America   8888.0
# 15   43.0        NaN  America   8300.0
# 16   38.0  Hyderabad     Asia  54666.0
# 17    NaN    newyork  America  67666.0
# 18   27.0    newyork  America   8888.0
# 19   31.0    Edmonto   Canada      NaN
# 20   34.0      Congo   Africa  34432.0
# 21   32.0     Angola   Africa  34534.0
# 22   26.0    Finland   Europe  33451.0
# 23   27.0     London   Europe      NaN

# %%
gh=pd.read_csv('hrdata1.csv')

# %%
gh
# Out:
#              Name  HireDate   Salary  SickDaysremaining
# 0  Graham Chapman  03/15/14  50000.0                 10
# 1     John Cleese  06/01/15  65000.0                  8
# 2       Eric Idle  05/12/14  45000.0                 10
# 3     Terry Jones  11/01/13  70000.0                  3
# 4   Terry Gilliam  08/12/14  48000.0                  7
# 5   Michael Palin  05/23/13  66000.0                  8

# %%
gh1=to_datetime(gh['HireDate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-128918c20315> in <module>
# ----> 1 gh1=to_datetime(gh['HireDate'])
#
# NameError: name 'to_datetime' is not defined

# %%
u2=pd.read_csv('HRdata.csv',
               index_col='Employee Name',
               parse_dates=['Hired'],
               header=0,
               names=['Employee Name','Hired','Sick Leaves taken'])
print(u2)
# Out:
#                    Hired  Sick Leaves taken
# Employee Name
# Jaya          2018-12-24                 13
# hARA          2018-12-24                 12
# ERT           2018-12-24                 34
# ASF           2018-12-24                 12
# ER            2018-12-24                 22
# TE            2018-12-24                 98

# %%
u2['Sick Leaves taken'].plot.bar()

# %%
import datetime

# %%
dt=datetime.datetime.now()
print(dt)
# Out:
# 2021-08-29 09:48:26.019337

# %%
print(dt + pd.to_timedelta(10,unit='D'))
# Out:
# 2021-09-08 09:36:34.169897

# %%
gh['Day']=gh['HireDate'].dt.day
gh['Month']=gh['HireDate'].dt.month
gh['Year']=gh['HireDate'].dt.year
print(gh)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-140d56f7adec> in <module>
# ----> 1 gh['Day']=gh['HireDate'].dt.day
#       2 gh['Month']=gh['HireDate'].dt.month
#       3 gh['Year']=gh['HireDate'].dt.year
#       4 print(gh)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
print(type(gh['HireDate'][2]))
# Out:
# <class 'str'>

# %%
gh=pd.read_csv('hrdata1.csv',
              index_col='Name',
              parse_dates=['HireDate'],
              header=0,
              names=['Name','HireDate','Salary','SickDaysremaining'])
gh
# Out:
#                  HireDate   Salary  SickDaysremaining
# Name
# Graham Chapman 2014-03-15  50000.0                 10
# John Cleese    2015-06-01  65000.0                  8
# Eric Idle      2014-05-12  45000.0                 10
# Terry Jones    2013-11-01  70000.0                  3
# Terry Gilliam  2014-08-12  48000.0                  7
# Michael Palin  2013-05-23  66000.0                  8

# %%
print(type(gh['HireDate'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
import datetime

# %%
t=datetime.datetime.now()
print(t)
# Out:
# 2021-08-29 10:29:55.648840

# %%
gh['Day']=gh['HireDate'].dt.day
gh['Month']=gh['HireDate'].dt.month
gh['Year']=gh['HireDate'].dt.year
print(gh)
# Out:
#                  HireDate   Salary  SickDaysremaining  Day  Month  Year
# Name
# Graham Chapman 2014-03-15  50000.0                 10   15      3  2014
# John Cleese    2015-06-01  65000.0                  8    1      6  2015
# Eric Idle      2014-05-12  45000.0                 10   12      5  2014
# Terry Jones    2013-11-01  70000.0                  3    1     11  2013
# Terry Gilliam  2014-08-12  48000.0                  7   12      8  2014
# Michael Palin  2013-05-23  66000.0                  8   23      5  2013
