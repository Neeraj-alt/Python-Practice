# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
r=['sun','mon','tue','wed','thur','fri','sat']
h=[12,23,24,34,45,23,56]
y=sns.stripplot(r,h)
y.set(xlabel='Days',ylabel='Values')
plt.title('Graph')
plt.show()

# %%
o=pd.read_csv('emptest.csv')
o
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.violinplot(x='Age',data=o)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
i=pd.read_csv('iris.csv')
print(i)
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
a=sns.stripplot(x='class',y='sepal length',data=i)
plt.title('Graph')
plt.show()

# %%
g=sns.swarmplot(x='class',y='sepal length',data=i)

# %%
i['class'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: class, dtype: int64

# %%
p=pd.read_csv('titanic.csv')
p
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
p.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
p['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
p['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(p['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
p['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(p['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
e=sns.catplot(x='Pclass',y='Survived',hue='Sex',data=p,kind='bar')
plt.show()

# %%
e=sns.catplot(x='Pclass',y='Survived',hue='Sex',data=p,kind='violin')
plt.show()

# %%
w=sns.load_dataset("tips")
print(w)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='total_bill',data=w)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot(x='total_bill',data=w,bins=12)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(w['total_bill'],bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(w['total_bill'],bins=10,kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(w['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=w,hue='smoker',x='total_bill',col='time',kind='ecdf')

# %%
sns.jointplot(data=w,x='total_bill',y='tip')

# %%
sns.rugplot(data=w,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=w,hue='smoker',x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=w,hue='smoker',x='day',y='total_bill',palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
j=sns.load_dataset('mpg')

# %%
j
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(data=j,x='horsepower',y='weight')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.lineplot(x='horsepower',y='weight',data=j)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.relplot(data=j,x='horsepower',y='weight')

# %%
sns.regplot(data=j,x='horsepower',y='weight')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.lmplot(data=j,x='horsepower',y='weight')

# %%
sns.boxplot(data=j,x='horsepower')
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.jointplot(data=j,x='horsepower',y='weight')

# %%
sns.stripplot(data=j,x='origin',y='weight')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.swarmplot(data=j,x='origin',y='weight')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.catplot(data=j,x='origin',y='weight',kind='box')

# %%
sns.catplot(data=j,x='origin',y='weight',kind='point')

# %%
y=sns.load_dataset('flights')

# %%
t=y.pivot('year','month','passengers')

# %%
t
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(t)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
